# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/파데분
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/파데분

# %%
import pandas as pd

df = pd.read_csv('mapo_df.csv')
df
# Out:
#    행정동명    세대수  남자인구수  여자인구수  행정통수   견인수
# 0   공덕동  18651  17169  19571    43   774
# 1   아현동  11713  13090  14886    26   190
# 2   도화동   9299   9834  10839    21   530
# 3   용강동   9268  10040  11238    20   252
# 4   대흥동   8801   7048   7432    22   373
# 5   염리동   7786   8011   8749    19   498
# 6   신수동   9991  10830  11365    22   415
# 7   망원동  18596  17507  19997    57  1041
# 8   서교동  15366  11071  13320    38  2734
# 9   합정동   9247   7623   8946    23   963
# 10  성산동  28931  26098  31542    59   361
# 11  연남동   8460   6848   7607    22   545
# 12  상암동  12720  14135  15841    28   290

# %%
bus_stop = pd.read_csv('서울특별시 마포구 버스정류소 위치정보_20230705.csv',encoding='cp949')
bus_stop
# Out:
#         연번    정류소번호        정류소명         X좌표        Y좌표         PNU코드  \
# 0      1.0  13019.0      동교동삼거리  126.929520  37.557765  1.144012e+18
# 1      2.0  13025.0         이대역  126.947271  37.556876  1.144011e+18
# 2      3.0  14001.0         마포역  126.947962  37.540900  1.144010e+18
# 3      4.0  14002.0         마포역  126.946785  37.540277  1.144010e+18
# 4      5.0  14003.0         공덕역  126.950905  37.543605  1.144010e+18
# ..     ...      ...         ...         ...        ...           ...
# 594  595.0  14996.0       백합아파트  126.900930  37.557951  1.144012e+18
# 595  596.0  14997.0       백합아파트  126.901071  37.557939  1.144012e+18
# 596  597.0  14998.0  서강대교북단(가상)  126.928083  37.543089  1.144012e+18
# 597  598.0  19600.0    마포대교(가상)  126.940812  37.537239  1.144011e+18
# 598  599.0  19601.0    마포대교(가상)  126.941799  37.537519  1.144011e+18
#
#                       지번주소         행정동코드    우편번호  데이터기준일자  Unnamed: 10
# ...

# %%
sport_df = pd.read_csv('공원 내 체육시설 현황.csv',encoding='cp949')
sport_df
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-9-92c4e6bc0da8> in <cell line: 1>()
# ----> 1 sport_df = pd.read_csv('공원 내 체육시설 현황.csv',encoding='cp949')
#       2 sport_df
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...
