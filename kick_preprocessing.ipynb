# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/파데분
# Out:
# /content/drive/MyDrive/파데분

# %%
import pandas as pd
mapo_parking_lot = pd.read_csv('마포구_주차장.csv',encoding ='cp949')
mapo_parking_lot
# Out:
#       연번           위치                   행정동    설치연도  Unnamed: 4
# 0    1.0    대흥역 1번 출구   서울특별시 마포구 대흥동 216-4  2022.0         NaN
# 1    2.0  마포구청역 3번 출구   서울특별시 마포구 성산동 592-6  2022.0         NaN
# 2    3.0    아현역 4번 출구  서울특별시 마포구 아현동 329-15  2022.0         NaN
# 3    4.0    신촌역 7번 출구   서울특별시 마포구 노고산동 57-2  2022.0         NaN
# 4    5.0    망원역 2번 출구  서울특별시 마포구 망원동 377-18  2022.0         NaN
# 5    6.0    공덕역 5번 출구  서울특별시 마포구 공덕동 255-10  2022.0         NaN
# 6    7.0   광흥창역 5번 출구   서울특별시 마포구 창전동 146-6  2022.0         NaN
# 7    8.0   애오개역 4번 출구   서울특별시 마포구 아현동 607-1  2022.0         NaN
# 8    9.0    이대역 5번 출구     서울특별시 마포구 대흥동 2-6  2022.0         NaN
# 9   10.0  마포구청역 5번 출구   서울특별시 마포구 성산동 266-1  2022.0         NaN
# 10  11.0       합정역 9번         서울특별시 마포구 서교동  2021.0         NaN
# 11  12.0       합정역10번         서울특별시 마포구 서교동  2021.0         NaN
# 12  13.0       합정역 8번         서울특별시 마포구 합정동  2021.0         NaN
# 13  14.0       합정역 8번         서울특별시 마포구 합정동  2021.0         NaN
# ...

# %%
user_parking = pd.read_csv('사용자_주차.csv')
user_parking
# Out:
#             번호         신고일   구정보                      주소                  유형  \
# 0            1  2021-07-15  영등포구   서울특별시 영등포구 여의도동 84-10  보도와 차도가 구분된 도로의 차도
# 1            2  2021-07-15  영등포구  서울특별시 영등포구 영등포동1가 97-4               보도 중앙
# 2            3  2021-07-15   동작구    서울특별시 동작구 노량진동 231-2  보도와 차도가 구분된 도로의 차도
# 3            4  2021-07-15   동작구     서울특별시 동작구 노량진동 54-3       버스정류장, 택시 승강장
# 4            5  2021-07-15   동작구   서울특별시 동작구 신대방동 460-30  보도와 차도가 구분된 도로의 차도
# ...        ...         ...   ...                     ...                 ...
# 123722  123723  2023-08-31  동대문구   서울특별시 동대문구 답십리동 80-10                불편신고
# 123723  123724  2023-08-31  동대문구   서울특별시 동대문구 전농동 150-10                불편신고
# 123724  123725  2023-08-31  동대문구   서울특별시 동대문구 전농동 150-56                불편신고
# 123725  123726  2023-08-31  동대문구   서울특별시 동대문구 전농동 584-21                불편신고
# 123726  123727  2023-08-31   관악구   서울특별시 관악구 봉천동 1529-47            빨리 가져가세요
#
#                조치일
# 0       2021-07-15
# ...

# %%
#user_parking = user_parking[user_parking['구정보'] == '마포구']
#print(len(user_parking))#마포구는 12184개
#print(user_parking)

user_parking = user_parking[user_parking['주소'].str.contains('마포')]
user_parking
# Out:
#             번호         신고일  구정보                    주소                  유형  \
# 10          11  2021-07-15  마포구    서울특별시 마포구 상암동 1709                  기타
# 17          18  2021-07-15  마포구  서울특별시 마포구 연남동 482-21  보도와 차도가 구분된 도로의 차도
# 21          22  2021-07-15  마포구  서울특별시 마포구 연남동 260-65  보도와 차도가 구분된 도로의 차도
# 35          36  2021-07-16  마포구    서울특별시 마포구 상암동 1695       버스정류장, 택시 승강장
# 37          38  2021-07-16  마포구  서울특별시 마포구 연남동 226-14       버스정류장, 택시 승강장
# ...        ...         ...  ...                   ...                 ...
# 123413  123414  2023-08-30  마포구     서울특별시 마포구 합정동 404             차도 불법주차
# 123414  123415  2023-08-30  마포구   서울특별시 마포구 합정동 402-1           횡단보도 통행방해
# 123427  123428  2023-08-30  마포구     서울특별시 마포구 서교동 415             차도 불법주차
# 123428  123429  2023-08-30  마포구     서울특별시 마포구 서교동 415             차도 불법주차
# 123436  123437  2023-08-30  마포구     서울특별시 마포구 합정동 423             차도 불법주차
#
#                조치일
# 10      2021-07-15
# 17      2021-07-15
# ...

# %%
'''
user_parking = user_parking.drop_duplicates(subset=['주소'])# 주소가 중복이 안되는 행은 2404개
user_parking
'''
# Out:
#             번호         신고일  구정보                    주소                  유형  \
# 10          11  2021-07-15  마포구    서울특별시 마포구 상암동 1709                  기타
# 17          18  2021-07-15  마포구  서울특별시 마포구 연남동 482-21  보도와 차도가 구분된 도로의 차도
# 21          22  2021-07-15  마포구  서울특별시 마포구 연남동 260-65  보도와 차도가 구분된 도로의 차도
# 35          36  2021-07-16  마포구    서울특별시 마포구 상암동 1695       버스정류장, 택시 승강장
# 37          38  2021-07-16  마포구  서울특별시 마포구 연남동 226-14       버스정류장, 택시 승강장
# ...        ...         ...  ...                   ...                 ...
# 121426  121427  2023-08-18  마포구   서울특별시 마포구 신수동 84-12             차도 통행장애
# 122545  122546  2023-08-24  마포구  서울특별시 마포구 공덕동 384-65          통행장애 치워주세요
# 122841  122842  2023-08-25  마포구  서울특별시 마포구 서교동 404-11             차도 통행장애
# 123188  123189  2023-08-29  마포구  서울특별시 마포구 망원동 404-26             차도 불법주차
# 123191  123192  2023-08-29  마포구  서울특별시 마포구 망원동 414-16             차도 불법주차
#
#                조치일
# 10      2021-07-15
# 17      2021-07-15
# ...

# %%
#원본에서 주소에 '마포'가 포함된 정보만 저장

user_parking.to_csv('마포구_견인정보.csv')
